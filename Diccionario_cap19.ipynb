# %% [markdown]
# ### LITERAL SYNTAX

# %%
d = {}

# %% [markdown]
# Crea un diccionario

# %%
d = {'key' : 'value'}

# %% [markdown]
# Crea un diccionario con una llave y un valor

# %%
d = {**otherdict}
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[42], line 1
# ----> 1 d = {**otherdict}
#
# NameError: name 'otherdict' is not defined

# %% [markdown]
# Hace una copia de otro diccionario

# %%
d = {**otherdict, **yetanotherdict}

# %% [markdown]
# Actualiza la copia del diccionario con otro diccionario

# %% [markdown]
# ### DICT COMPREHENSION

# %%
d = {k:v for k, v in [('key', 'value',)]} 
d

# %% [markdown]
# Extrae k y v

# %% [markdown]
# ### BUILT-IN CLASS:DICT()

# %%
d = dict()
d

# %% [markdown]
# Crea un diccionario vacio

# %%
d = dict(key='value') 
d

# %% [markdown]
# Crea un diccionario en el que se le da valor a la key

# %%
d = dict([('key','value')])
d

# %% [markdown]
# Crea un diccionario con una key y un valor

# %%
d = dict(**otherdict)

# %% [markdown]
# Hace la copia de otro diccionario

# %% [markdown]
# ### MODIFYING A DICT

# %%
d['newkey'] = 42

# %% [markdown]
# crea una nueva entrada en el diccionario con clave y valor

# %%
d['new_list'] = [1, 2, 3]
d
# Out:
# {'new_list': [1, 2, 3]}

# %% [markdown]
# Crea una lista en el diccionario

# %%
d['new_dict'] = {'nested_dict' : 1}
d
# Out:
# {'new_list': [1, 2, 3], 'new_dict': {'nested_dict': 1}}

# %% [markdown]
# Crea una entrada en el diccionario con clave y valor dentro de otro diccionario

# %%
del d['newkey']

# %% [markdown]
# Elimina una entrada del dict

# %%
mydict = {}

# %% [markdown]
# Crea un diccionario vacio

# %%
mydict['not there']
d
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 mydict['not there']
#       2 d
#
# KeyError: 'not there'

# %% [markdown]
# Da error porque no existe esa clave

# %%
value = mydict.get(key, default_value)

# %% [markdown]
# Devuelve el valor de una clave y valor por defecto

# %%
mydict = {}
print(mydict)
print(mydict.get("foo","bar")) 
print (mydict)
print(mydict.setdefault("foo", "bar"))
print(mydict)
# Out:
# {}
# bar
# {}
# bar
# {'foo': 'bar'}

# %%
try:
    value = mydict[key]
except KeyError:
    value = default_value
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[39], line 2
#       1 try:
# ----> 2     value = mydict[key]
#       3 except KeyError:
#       4     value = default_value
#
# NameError: name 'key' is not defined

# %% [markdown]
# Intenta igualar una variable a una clave  y le da error por lo que da un valor por defecto

# %%
if key in mydict:
    value = mydict[key]
else:
    value = default_value

# %% [markdown]
# Si encuentra la clave en el diccionario guarda su valor en la variable si no le da un valor por defecto

# %%
d = {'a': 1, 'b': 2, 'c':3}
for key in d:
    print(key, d[key])
# Out:
# a 1
# b 2
# c 3

# %% [markdown]
# Crea un diccionario con claves con valores
