# %%
D = {} # DICCIONARIO VACIO

# %%
D = {"name": "Bob", "age": 40}

# %%
E = {"cto": {"name": "Bob", "age": 40}, "coo": {"nombre":"juan", "age":35}} #DICCIONARIO CON DOS ITEMS

# %%
D = dict(name ="Bob", age=40) #CREAR UN DICCIONARIO CON ESTO

# %%
D = dict([("name", "Bob"), ("age", 40)]) #CREAR UN DICCIONARIO CON ESTO

# %%
D = dict(zip(keylist, valueslist)) #CREAR UN DICCIONARIO CON ESTO

# %%
D = dict.fromkeys(["name", "age"], 0) #CREA UN DICCIONARIO Y DESPUS PASANDOLE UN PARAMETRO PARA ASIGNARLE UN VALOR

# %%
D["name"] # DEVUELVE EL VALOR ASOCIADO A LA KEY
# Out:
# 'Bob'

# %%
E["cto"]["age"] # DEVUELVE EL VALOR COMO SI FUESE E[0][1]
# Out:
# 35

# %%
"age" in D #BUSCA SI ESTÁ UNA KEY EN EL DICCIONARIO
# Out:
# True

# %%
D.keys() #DEVUELVE LAS KEYS DE DICC
# Out:
# dict_keys(['name', 'age'])

# %%
D.values() #DEVUELVE LOS VALORES DE DICC

# %%
D.items() #DEVUELVE TODA EL DICC
# Out:
# dict_items([('name', 'Bob'), ('age', 40)])

# %%
D.copy() #CREA UNA COPIA DEL DICC Y LO DEVUELVE
# Out:
# {'name': 'Bob', 'age': 40}

# %%
D.clear() #VACIA UN DICC

# %%
D.update(E) # REFRESCA UN DICCIONARIO CON LOS DATOS DEL OTRO, O LOS CONCATENA

# %%
D.get(key, default?) # Busca una clave, si no existe devuelve default o None si no se pone default?

# %%
D.pop(key, default?) #Borra una clave y devuelve su valor. Si no existe devuelve default

# %%
D.setdefault(key, default?) # Devuelve el valor de una clave. Si no existe la crea con default y lo devuelve

# %%
D.popitem() # Borra y devuelve cualquier par (clave, valor) del diccionario

# %%
len(D) #Cantidad de elementos del diccionario

# %%
D[key] = 42 #Cambia o añade valor de esa clave

# %%
del D[key] #Borra esa llave del dicccionario

# %%
list(D.keys()) # Lista con todas las claves

# %%
D1.keys() & D2.keys() # Devuelve las llaves comunes entre dos diccionarios

# %%
D.viewkeys(), D.viewvalues() #Vistas dinamicas de claves/valores

# %%
D = {x: x*2 for x in range(10)} #Crea un diccionario con claves x y valores x*2 de 0 a 9
