# %%
a = [1, 2, 3, 4, 5]

# %%
#Añadir valores
a.append(6) 
a.append(7)
a.append(7)
#Añadir valores de otra lista
b = [8, 9]
a.append(b)
#Añadir otro tipo de elemento
my_string = "Hola"
a.append(my_string)
#Extender Lista
a.extend(b)
#Extiende valores desde 0
a.extend(range(3))
#Encuentra valor y devuelve posicion
a.index(7)
#Inserta en una posicion un valor
a.insert(0, 5)
#Borra un valor y devuelve la posicion del valor borrado
a.pop(4)
#Borra el primer valor encontrado que coincida
a.remove(5)
#Invierte la lista
a.reverse()
